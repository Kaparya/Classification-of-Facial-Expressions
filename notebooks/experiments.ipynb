# %%
from datasets import load_dataset
import torch
import warnings
warnings.filterwarnings('ignore')

# %%
device = torch.device("cpu")
if torch.cuda.is_available():
    device = torch.device("cuda")
    print('Found GPU. Device name:', torch.cuda.get_device_name(0))
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print(f'Found MPS device. Recommended max memory: {torch.mps.recommended_max_memory() / 1024 / 1024 / 1024:.2f} GB')
else:
    print ("Devices not found. Use cpu")

print(device)
# Out:
# Found MPS device. Recommended max memory: 24.96 GB
# mps

# %%
# ds = load_dataset("AbstractTTS/IEMOCAP")
# ds
# train_data = ds['train']
# print('Length of train data: ', len(train_data))
# print('Features of train data: ', train_data.features)
# train_data[0]
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'frustrated', 'angry', 'sad', 'disgust', 'excited', 'fear', 'neutral', 'surprise', 'happy', 'EmoAct', 'EmoVal', 'EmoDom', 'gender', 'transcription', 'major_emotion', 'speaking_rate', 'pitch_mean', 'pitch_std', 'rms', 'relative_db'],
#         num_rows: 10039
#     })
# })

# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("orvile/ravdess-dataset")

# print("Path to dataset files:", path)
# Out:
# Resuming download from 137363456 bytes (25477660786 bytes left)...
# Resuming download to /Users/kaparya/.cache/kagglehub/datasets/orvile/ravdess-dataset/1.archive (137363456/25615024242) bytes left.
# 100%|██████████| 23.9G/23.9G [58:08<00:00, 7.30MB/s]
# Extracting files...
# Path to dataset files: /Users/kaparya/.cache/kagglehub/datasets/orvile/ravdess-dataset/versions/1
